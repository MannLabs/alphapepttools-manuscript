# %% [markdown]
# # Create RNA adata
#
#
# 1. Lehtiö, J. et al. Proteogenomics of non-small cell lung cancer reveals molecular subtypes associated with specific therapeutic targets and immune-evasion mechanisms. Nat Cancer 2, 1224–1242 (2021).
#
# See Supplementary File 1

# %%
import anndata as ad
import pandas as pd

# %%
expression_data = (
    pd.read_excel(
        "./raw/lethioe2021_SI1.xlsx", sheet_name="Table2-Mehylation"
    )
    .set_index(["GeneSymbol", "probeID", "ID"])
    .T
)

adata = ad.AnnData(
    X=expression_data.values,
    obs=expression_data.index.to_frame(index=False, name="sample_id").set_index(
        "sample_id"
    ),
    var=expression_data.columns.to_frame(index=False).set_index("GeneSymbol"),
)
adata.X = adata.X.astype(float)
# Out:
# /Users/lucas-diedrich/mamba/envs/at-paper-multimodal/lib/python3.13/functools.py:934: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /var/folders/py/838_q5nd6594y27wbrpkhl3h0000gn/T/ipykernel_15457/2697003937.py:9: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   adata = ad.AnnData(

# %%
metadata = pd.read_csv(
    "./raw/metadata.tsv", sep="\t", index_col=0
).drop(columns=["tmt_set_and_label"])
adata.obs = adata.obs.merge(metadata, left_index=True, right_index=True)

# %%
adata.write_h5ad("./pp/karlsson2014_nslc_methylation.h5ad")

# %%
from session_info2 import session_info

session_info()
# Out:
# anndata	0.13.3.post0
# pandas	3.0.5
# ----	----
# Python	3.13.15 | packaged by conda-forge | (main, Sep  2 2026, 21:53:23) [Clang 21.1.8 ]
# OS	macOS-26.5.2-arm64-arm-64bit-Mach-O
# Updated	2026-09-07 16:43
